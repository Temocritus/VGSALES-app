# %%
#Importing the necessary modules

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML
import streamlit as st
df = pd.read_csv("vgsales.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Data frame exploration

df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#Data cleaning

# %%
#assessing for missing values

df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
#eliminationg the missing values and corresponding rows

df2 =df.dropna()
df2
# Out:
# 2021-11-06 04:25:55.798 INFO    numexpr.utils: NumExpr defaulting to 4 threads.
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
# ...

# %%
#checking for corrections

df2.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
#assessing the dataframe for duplicates and eliminating the duplicates from the dataframe

df2.drop_duplicates()
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#Data Processing

# %%
# 1. Finding the leading gaming platforms wrt sales, both globally and regionally

# %%
       # i.finding the leading console globally
    
df3 = df.groupby(['Platform']).agg({'Global_Sales': 'sum'}).reset_index()
df3
# Out:
#    Platform  Global_Sales
# 0      2600         97.08
# 1       3DO          0.10
# 2       3DS        247.46
# 3        DC         15.97
# 4        DS        822.49
# 5        GB        255.45
# 6       GBA        318.50
# 7        GC        199.36
# 8       GEN         28.36
# 9        GG          0.04
# 10      N64        218.88
# 11      NES        251.07
# 12       NG          1.44
# 13       PC        258.82
# 14     PCFX          0.03
# 15       PS        730.66
# 16      PS2       1255.64
# 17      PS3        957.84
# 18      PS4        278.10
# 19      PSP        296.28
# 20      PSV         61.93
# 21      SAT         33.59
# 22      SCD          1.87
# 23     SNES        200.05
# 24     TG16          0.16
# 25       WS          1.42
# 26      Wii        926.71
# 27     WiiU         81.86
# 28     X360        979.96
# 29       XB        258.26
# 30     XOne        141.06

# %%
  #rearranging the global sales in descending order 
    
df4 = df3.sort_values('Global_Sales',ascending = False)
df4
# Out:
#    Platform  Global_Sales
# 16      PS2       1255.64
# 28     X360        979.96
# 17      PS3        957.84
# 26      Wii        926.71
# 4        DS        822.49
# 15       PS        730.66
# 6       GBA        318.50
# 19      PSP        296.28
# 18      PS4        278.10
# 13       PC        258.82
# 29       XB        258.26
# 5        GB        255.45
# 11      NES        251.07
# 2       3DS        247.46
# 10      N64        218.88
# 23     SNES        200.05
# 7        GC        199.36
# 30     XOne        141.06
# 0      2600         97.08
# 27     WiiU         81.86
# 20      PSV         61.93
# 21      SAT         33.59
# 8       GEN         28.36
# 3        DC         15.97
# 22      SCD          1.87
# 12       NG          1.44
# 25       WS          1.42
# 24     TG16          0.16
# 1       3DO          0.10
# 9        GG          0.04
# 14     PCFX          0.03

# %%
   #Getting top 10 leading platforms 

Global=df4.head(10)
Global
# Out:
#    Platform  Global_Sales
# 16      PS2       1255.64
# 28     X360        979.96
# 17      PS3        957.84
# 26      Wii        926.71
# 4        DS        822.49
# 15       PS        730.66
# 6       GBA        318.50
# 19      PSP        296.28
# 18      PS4        278.10
# 13       PC        258.82

# %%
#Plotting  the bar chart of popular sales wrt sales

Global.plot.bar(x="Platform", y="Global_Sales", rot=70, title="Sales by Gaming Platform Globally, Top 10");

plt.show(block=True)

# %%
  # ii. Deducing the leading platforms in the North America region
    
df5 = df.groupby(['Platform']).agg({'NA_Sales': 'sum'}).reset_index()
df5
# Out:
#    Platform  NA_Sales
# 0      2600     90.60
# 1       3DO      0.00
# 2       3DS     78.87
# 3        DC      5.43
# 4        DS    390.71
# 5        GB    114.32
# 6       GBA    187.54
# 7        GC    133.46
# 8       GEN     19.27
# 9        GG      0.00
# 10      N64    139.02
# 11      NES    125.94
# 12       NG      0.00
# 13       PC     93.28
# 14     PCFX      0.00
# 15       PS    336.51
# 16      PS2    583.84
# 17      PS3    392.26
# 18      PS4     96.80
# 19      PSP    108.99
# 20      PSV     16.20
# 21      SAT      0.72
# 22      SCD      1.00
# 23     SNES     61.23
# 24     TG16      0.00
# 25       WS      0.00
# 26      Wii    507.71
# 27     WiiU     38.32
# 28     X360    601.05
# 29       XB    186.69
# 30     XOne     83.19

# %%
#descending order

America = df5.sort_values('NA_Sales',ascending = False)
America
# Out:
#    Platform  NA_Sales
# 28     X360    601.05
# 16      PS2    583.84
# 26      Wii    507.71
# 17      PS3    392.26
# 4        DS    390.71
# 15       PS    336.51
# 6       GBA    187.54
# 29       XB    186.69
# 10      N64    139.02
# 7        GC    133.46
# 11      NES    125.94
# 5        GB    114.32
# 19      PSP    108.99
# 18      PS4     96.80
# 13       PC     93.28
# 0      2600     90.60
# 30     XOne     83.19
# 2       3DS     78.87
# 23     SNES     61.23
# 27     WiiU     38.32
# 8       GEN     19.27
# 20      PSV     16.20
# 3        DC      5.43
# 22      SCD      1.00
# 21      SAT      0.72
# 1       3DO      0.00
# 14     PCFX      0.00
# 12       NG      0.00
# 9        GG      0.00
# 24     TG16      0.00
# 25       WS      0.00

# %%
NA = America.head(10)
NA
# Out:
#    Platform  NA_Sales
# 28     X360    601.05
# 16      PS2    583.84
# 26      Wii    507.71
# 17      PS3    392.26
# 4        DS    390.71
# 15       PS    336.51
# 6       GBA    187.54
# 29       XB    186.69
# 10      N64    139.02
# 7        GC    133.46

# %%
# VIsualising
NA.plot.bar(x="Platform", y="NA_Sales", rot=70, title="Game Sales in North America, Top 10 Platforms");

plt.show(block=True)

# %%
  # European Region
    
Europe = df.groupby(['Platform']).agg({'EU_Sales': 'sum'}).reset_index()
Europe
# Out:
#    Platform  EU_Sales
# 0      2600      5.47
# 1       3DO      0.00
# 2       3DS     58.52
# 3        DC      1.69
# 4        DS    194.65
# 5        GB     47.82
# 6       GBA     75.25
# 7        GC     38.71
# 8       GEN      5.52
# 9        GG      0.00
# 10      N64     41.06
# 11      NES     21.15
# 12       NG      0.00
# 13       PC    139.68
# 14     PCFX      0.00
# 15       PS    213.60
# 16      PS2    339.29
# 17      PS3    343.71
# 18      PS4    123.70
# 19      PSP     68.25
# 20      PSV     16.33
# 21      SAT      0.54
# 22      SCD      0.36
# 23     SNES     19.04
# 24     TG16      0.00
# 25       WS      0.00
# 26      Wii    268.38
# 27     WiiU     24.23
# 28     X360    280.58
# 29       XB     60.95
# 30     XOne     45.65

# %%
EU1 = Europe.sort_values('EU_Sales',ascending = False)
EU1
# Out:
#    Platform  EU_Sales
# 17      PS3    343.71
# 16      PS2    339.29
# 28     X360    280.58
# 26      Wii    268.38
# 15       PS    213.60
# 4        DS    194.65
# 13       PC    139.68
# 18      PS4    123.70
# 6       GBA     75.25
# 19      PSP     68.25
# 29       XB     60.95
# 2       3DS     58.52
# 5        GB     47.82
# 30     XOne     45.65
# 10      N64     41.06
# 7        GC     38.71
# 27     WiiU     24.23
# 11      NES     21.15
# 23     SNES     19.04
# 20      PSV     16.33
# 8       GEN      5.52
# 0      2600      5.47
# 3        DC      1.69
# 21      SAT      0.54
# 22      SCD      0.36
# 25       WS      0.00
# 24     TG16      0.00
# 1       3DO      0.00
# 9        GG      0.00
# 12       NG      0.00
# 14     PCFX      0.00

# %%
EU = EU1.head(10)
EU
# Out:
#    Platform  EU_Sales
# 17      PS3    343.71
# 16      PS2    339.29
# 28     X360    280.58
# 26      Wii    268.38
# 15       PS    213.60
# 4        DS    194.65
# 13       PC    139.68
# 18      PS4    123.70
# 6       GBA     75.25
# 19      PSP     68.25

# %%
# VIsualising

EU.plot.bar(x="Platform", y="EU_Sales", rot=70, title="Game Sales in North America, Top 10 Platforms");

plt.show(block=True)

# %%
  # iii. Japan Region
    
Japan= df.groupby(['Platform']).agg({'JP_Sales': 'sum'}).reset_index()
Japan
# Out:
#    Platform  JP_Sales
# 0      2600      0.00
# 1       3DO      0.10
# 2       3DS     97.35
# 3        DC      8.56
# 4        DS    175.57
# 5        GB     85.12
# 6       GBA     47.33
# 7        GC     21.58
# 8       GEN      2.67
# 9        GG      0.04
# 10      N64     34.22
# 11      NES     98.65
# 12       NG      1.44
# 13       PC      0.17
# 14     PCFX      0.03
# 15       PS    139.82
# 16      PS2    139.20
# 17      PS3     79.99
# 18      PS4     14.30
# 19      PSP     76.79
# 20      PSV     20.96
# 21      SAT     32.26
# 22      SCD      0.45
# 23     SNES    116.55
# 24     TG16      0.16
# 25       WS      1.42
# 26      Wii     69.35
# 27     WiiU     12.79
# 28     X360     12.43
# 29       XB      1.38
# 30     XOne      0.34

# %%
JP1 = Japan.sort_values('JP_Sales',ascending = False)

# %%
JP = JP1.head(10)
JP
# Out:
#    Platform  JP_Sales
# 4        DS    175.57
# 15       PS    139.82
# 16      PS2    139.20
# 23     SNES    116.55
# 11      NES     98.65
# 2       3DS     97.35
# 5        GB     85.12
# 17      PS3     79.99
# 19      PSP     76.79
# 26      Wii     69.35

# %%
# VIsualising

JP.plot.bar(x="Platform", y="JP_Sales", rot=70, title="Game Sales in Japan, Top 10 Platforms");

plt.show(block=True)

# %%
  # Rest of the world
Rest = df.groupby(['Platform']).agg({'Other_Sales': 'sum'}).reset_index()
Rest
# Out:
#    Platform  Other_Sales
# 0      2600         0.91
# 1       3DO         0.00
# 2       3DS        12.63
# 3        DC         0.27
# 4        DS        60.53
# 5        GB         8.20
# 6       GBA         7.73
# 7        GC         5.18
# 8       GEN         0.89
# 9        GG         0.00
# 10      N64         4.38
# 11      NES         5.31
# 12       NG         0.00
# 13       PC        24.86
# 14     PCFX         0.00
# 15       PS        40.91
# 16      PS2       193.44
# 17      PS3       141.93
# 18      PS4        43.36
# 19      PSP        42.19
# 20      PSV         8.45
# 21      SAT         0.07
# 22      SCD         0.05
# 23     SNES         3.22
# 24     TG16         0.00
# 25       WS         0.00
# 26      Wii        80.61
# 27     WiiU         6.45
# 28     X360        85.54
# 29       XB         8.72
# 30     XOne        11.92

# %%
Other1 = Rest.sort_values('Other_Sales',ascending = False)

# %%
Other = Other1.head(10)
Other
# Out:
#    Platform  Other_Sales
# 16      PS2       193.44
# 17      PS3       141.93
# 28     X360        85.54
# 26      Wii        80.61
# 4        DS        60.53
# 18      PS4        43.36
# 19      PSP        42.19
# 15       PS        40.91
# 13       PC        24.86
# 2       3DS        12.63

# %%
# VIsualising

Other.plot.bar(x="Platform", y="Other_Sales", rot=70, title="Game Sales for the rest of the world, Top 10 Platforms");

plt.show(block=True)

# %%
   # combining the top 10 leading Platforms' data frames
    
World = pd.concat([Global, NA, EU, JP, Other], axis=1)
World
# Out:
#    Platform  Global_Sales Platform  NA_Sales Platform  EU_Sales Platform  \
# 2       NaN           NaN      NaN       NaN      NaN       NaN      3DS
# 4        DS        822.49       DS    390.71       DS    194.65       DS
# 5       NaN           NaN      NaN       NaN      NaN       NaN       GB
# 6       GBA        318.50      GBA    187.54      GBA     75.25      NaN
# 7       NaN           NaN       GC    133.46      NaN       NaN      NaN
# 10      NaN           NaN      N64    139.02      NaN       NaN      NaN
# 11      NaN           NaN      NaN       NaN      NaN       NaN      NES
# 13       PC        258.82      NaN       NaN       PC    139.68      NaN
# 15       PS        730.66       PS    336.51       PS    213.60       PS
# 16      PS2       1255.64      PS2    583.84      PS2    339.29      PS2
# 17      PS3        957.84      PS3    392.26      PS3    343.71      PS3
# 18      PS4        278.10      NaN       NaN      PS4    123.70      NaN
# ...

# %%
  #dropping columns with similr names
    
World_sales=World.iloc[:,~World.columns.duplicated()]
World_sales
# Out:
#    Platform  Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 2       NaN           NaN       NaN       NaN     97.35        12.63
# 4        DS        822.49    390.71    194.65    175.57        60.53
# 5       NaN           NaN       NaN       NaN     85.12          NaN
# 6       GBA        318.50    187.54     75.25       NaN          NaN
# 7       NaN           NaN    133.46       NaN       NaN          NaN
# 10      NaN           NaN    139.02       NaN       NaN          NaN
# 11      NaN           NaN       NaN       NaN     98.65          NaN
# 13       PC        258.82       NaN    139.68       NaN        24.86
# 15       PS        730.66    336.51    213.60    139.82        40.91
# 16      PS2       1255.64    583.84    339.29    139.20       193.44
# 17      PS3        957.84    392.26    343.71     79.99       141.93
# 18      PS4        278.10       NaN    123.70       NaN        43.36
# 19      PSP        296.28       NaN     68.25     76.79        42.19
# ...

# %%
    # arranging the data frame in descending order wrt Global sales

Platforms= World_sales.sort_values('Global_Sales',ascending = False)
Platforms
# Out:
#    Platform  Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 16      PS2       1255.64    583.84    339.29    139.20       193.44
# 28     X360        979.96    601.05    280.58       NaN        85.54
# 17      PS3        957.84    392.26    343.71     79.99       141.93
# 26      Wii        926.71    507.71    268.38     69.35        80.61
# 4        DS        822.49    390.71    194.65    175.57        60.53
# 15       PS        730.66    336.51    213.60    139.82        40.91
# 6       GBA        318.50    187.54     75.25       NaN          NaN
# 19      PSP        296.28       NaN     68.25     76.79        42.19
# 18      PS4        278.10       NaN    123.70       NaN        43.36
# 13       PC        258.82       NaN    139.68       NaN        24.86
# 2       NaN           NaN       NaN       NaN     97.35        12.63
# 5       NaN           NaN       NaN       NaN     85.12          NaN
# 7       NaN           NaN    133.46       NaN       NaN          NaN
# ...

# %%
TopPlatforms = Platforms.head(10)
TopPlatforms
# Out:
#    Platform  Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 16      PS2       1255.64    583.84    339.29    139.20       193.44
# 28     X360        979.96    601.05    280.58       NaN        85.54
# 17      PS3        957.84    392.26    343.71     79.99       141.93
# 26      Wii        926.71    507.71    268.38     69.35        80.61
# 4        DS        822.49    390.71    194.65    175.57        60.53
# 15       PS        730.66    336.51    213.60    139.82        40.91
# 6       GBA        318.50    187.54     75.25       NaN          NaN
# 19      PSP        296.28       NaN     68.25     76.79        42.19
# 18      PS4        278.10       NaN    123.70       NaN        43.36
# 13       PC        258.82       NaN    139.68       NaN        24.86

# %%
  #Global sales dictate popularity of the gaming platform, thus platforms that are globally popular but not regionally popular are assigned a zero for the corresponding region
    
Popular_Consoles= TopPlatforms.replace(to_replace = np.nan, value =0)
Popular_Consoles
# Out:
#    Platform  Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 16      PS2       1255.64    583.84    339.29    139.20       193.44
# 28     X360        979.96    601.05    280.58      0.00        85.54
# 17      PS3        957.84    392.26    343.71     79.99       141.93
# 26      Wii        926.71    507.71    268.38     69.35        80.61
# 4        DS        822.49    390.71    194.65    175.57        60.53
# 15       PS        730.66    336.51    213.60    139.82        40.91
# 6       GBA        318.50    187.54     75.25      0.00         0.00
# 19      PSP        296.28      0.00     68.25     76.79        42.19
# 18      PS4        278.10      0.00    123.70      0.00        43.36
# 13       PC        258.82      0.00    139.68      0.00        24.86

# %%
#Plotting a line chart for all sales

plt.title('Top 10 popular platforms with respect to Game Sales')

plt.plot(Popular_Consoles['Platform'], Popular_Consoles['NA_Sales'], label='NA Sales')

plt.plot(Popular_Consoles['Platform'], Popular_Consoles['EU_Sales'], label='EU Sales')

plt.plot(Popular_Consoles['Platform'], Popular_Consoles['JP_Sales'], label='JP Sales')

plt.plot(Popular_Consoles['Platform'], Popular_Consoles['Other_Sales'], label ='Other Sales')

plt.plot(Popular_Consoles['Platform'], Popular_Consoles['Global_Sales'], label ='Global Sales')

plt.legend()

plt.show()

# %%
#2.Leading game Publishers/Developers

# %%
#leading puplbishers wrt to Global Sales

Game_Publishers = df.groupby(['Publisher']).agg({'Global_Sales': 'sum'}).reset_index()
Game_Publishers
# Out:
#                         Publisher  Global_Sales
# 0                 10TACLE Studios          0.11
# 1                      1C Company          0.10
# 2    20th Century Fox Video Games          1.94
# 3                          2D Boy          0.04
# 4                             3DO         10.12
# ..                            ...           ...
# 573                   id Software          0.03
# 574               imageepoch Inc.          0.04
# 575          inXile Entertainment          0.10
# 576                     mixi, Inc          0.86
# 577                  responDESIGN          0.13
#
# [578 rows x 2 columns]

# %%
# Descending order
Game_Publishers= Game_Publishers.sort_values('Global_Sales',ascending = False)
Game_Publishers
# Out:
#                        Publisher  Global_Sales
# 359                     Nintendo       1786.56
# 138              Electronic Arts       1110.32
# 21                    Activision        727.46
# 456  Sony Computer Entertainment        607.50
# 525                      Ubisoft        474.72
# ..                           ...           ...
# 375                    Ongakukan          0.01
# 96                      Commseed          0.01
# 495                       Takuyo          0.01
# 76                      Boost On          0.01
# 350                   Naxat Soft          0.01
#
# [578 rows x 2 columns]

# %%
 #Top 10
Leading_Publishers = Game_Publishers.head(10)
Leading_Publishers
# Out:
#                         Publisher  Global_Sales
# 359                      Nintendo       1786.56
# 138               Electronic Arts       1110.32
# 21                     Activision        727.46
# 456   Sony Computer Entertainment        607.50
# 525                       Ubisoft        474.72
# 494          Take-Two Interactive        399.54
# 488                           THQ        340.77
# 275  Konami Digital Entertainment        283.64
# 446                          Sega        272.99
# 347            Namco Bandai Games        254.09

# %%
# Visualisation of top Publishers wrt game sales

Leading_Publishers.plot.bar(x="Publisher", y="Global_Sales", rot=70, title="Top 10 Publishers in the worlds by Sales");

plt.show(block=True)

# %%
  
 # Popular publisher with respect to number of games in the list

# %%
# Determinig entries made by publisher. This informs on the numner of games per publisher
# transforming value counts to a dataframe

Publishers = (df['Publisher'].value_counts().rename_axis('unique_values').to_frame('Counts').reset_index())
Publishers
# Out:
#                     unique_values  Counts
# 0                 Electronic Arts    1351
# 1                      Activision     975
# 2              Namco Bandai Games     932
# 3                         Ubisoft     921
# 4    Konami Digital Entertainment     832
# ..                            ...     ...
# 573                Strategy First       1
# 574                        2D Boy       1
# 575                           Pow       1
# 576                     Square EA       1
# 577                       FunSoft       1
#
# [578 rows x 2 columns]

# %%
Top_publishers = Publishers.nlargest(10, 'Counts')

# %%
#renaming a colomn header

Popular_Publishers = Top_publishers.rename(columns={'unique_values': 'Publishers'})
Popular_Publishers
# Out:
#                      Publishers  Counts
# 0               Electronic Arts    1351
# 1                    Activision     975
# 2            Namco Bandai Games     932
# 3                       Ubisoft     921
# 4  Konami Digital Entertainment     832
# 5                           THQ     715
# 6                      Nintendo     703
# 7   Sony Computer Entertainment     683
# 8                          Sega     639
# 9          Take-Two Interactive     413

# %%
# Visualisation into a table
HTML(Popular_Publishers.to_html( classes= 'table table-striped table-bordered' ))
# Out:
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Publishers</th>
#       <th>Counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Electronic Arts</td>
#       <td>1351</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Activision</td>
#       <td>975</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Namco Bandai Games</td>
#       <td>932</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Ubisoft</td>
#       <td>921</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Konami Digital Entertainment</td>
#       <td>832</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>THQ</td>
#       <td>715</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Nintendo</td>
#       <td>703</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Sony Computer Entertainment</td>
#       <td>683</td>
#     </tr>
# ...

# %%
# Visualisation of game enties per Publisher

Popular_Publishers.plot.bar(x="Publishers", y="Counts", rot=70, title="Leading Publishers by game entries");

plt.show(block=True)

# %%
# 3. Market for new games wrt to popular genres
#this informs Publishers on which genre to make fornew games

# %%
Genre = df.groupby(['Genre']).agg({'Global_Sales': 'sum'}).reset_index()
Genre
# Out:
#            Genre  Global_Sales
# 0         Action       1751.18
# 1      Adventure        239.04
# 2       Fighting        448.91
# 3           Misc        809.96
# 4       Platform        831.37
# 5         Puzzle        244.95
# 6         Racing        732.04
# 7   Role-Playing        927.37
# 8        Shooter       1037.37
# 9     Simulation        392.20
# 10        Sports       1330.93
# 11      Strategy        175.12

# %%
Genre = Genre.sort_values('Global_Sales',ascending = False)
Genre
# Out:
#            Genre  Global_Sales
# 0         Action       1751.18
# 10        Sports       1330.93
# 8        Shooter       1037.37
# 7   Role-Playing        927.37
# 4       Platform        831.37
# 3           Misc        809.96
# 6         Racing        732.04
# 2       Fighting        448.91
# 9     Simulation        392.20
# 5         Puzzle        244.95
# 1      Adventure        239.04
# 11      Strategy        175.12

# %%
Popular_Genre = Genre.head(10)
Popular_Genre
# Out:
#            Genre  Global_Sales
# 0         Action       1751.18
# 10        Sports       1330.93
# 8        Shooter       1037.37
# 7   Role-Playing        927.37
# 4       Platform        831.37
# 3           Misc        809.96
# 6         Racing        732.04
# 2       Fighting        448.91
# 9     Simulation        392.20
# 5         Puzzle        244.95

# %%
Popular_Genre.plot.bar(x="Genre", y="Global_Sales", rot=70, title="best selling games globally");

plt.show(block=True)

# %%
# 4. Game sequels
# This considers high selling games for developers to make sequels to them

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#droping columns not needed to identify popular games

Games = df.drop(df.iloc[:, [0,3,5,6,7,8,9]], axis=1)
Games
# Out:
#                                                    Name Platform  \
# 0                                            Wii Sports      Wii
# 1                                     Super Mario Bros.      NES
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 4                              Pokemon Red/Pokemon Blue       GB
# ...                                                 ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA
# 16594                     Men in Black II: Alien Escape       GC
# 16595  SCORE International Baja 1000: The Official Game      PS2
# 16596                                        Know How 2       DS
# 16597                                  Spirits & Spells      GBA
#
#               Genre  Global_Sales
# 0            Sports         82.74
# 1          Platform         40.24
# 2            Racing         35.82
# 3            Sports         33.00
# ...

# %%
# Descending order
Games = Games.sort_values('Global_Sales',ascending = False)
Games
# Out:
#                                        Name Platform         Genre  \
# 0                                Wii Sports      Wii        Sports
# 1                         Super Mario Bros.      NES      Platform
# 2                            Mario Kart Wii      Wii        Racing
# 3                         Wii Sports Resort      Wii        Sports
# 4                  Pokemon Red/Pokemon Blue       GB  Role-Playing
# ...                                     ...      ...           ...
# 16186                           BattleForge       PC      Strategy
# 16187                        Jewel Quest II       PC        Puzzle
# 16188                      Toro to Morimori      PS3          Misc
# 16189  Sonic & All-Stars Racing Transformed       PC        Racing
# 16597                      Spirits & Spells      GBA      Platform
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# ...

# %%
# best candidates for sequels

Best_Candidates = Games.head(10)
Best_Candidates
# Out:
#                         Name Platform         Genre  Global_Sales
# 0                 Wii Sports      Wii        Sports         82.74
# 1          Super Mario Bros.      NES      Platform         40.24
# 2             Mario Kart Wii      Wii        Racing         35.82
# 3          Wii Sports Resort      Wii        Sports         33.00
# 4   Pokemon Red/Pokemon Blue       GB  Role-Playing         31.37
# 5                     Tetris       GB        Puzzle         30.26
# 6      New Super Mario Bros.       DS      Platform         30.01
# 7                   Wii Play      Wii          Misc         29.02
# 8  New Super Mario Bros. Wii      Wii      Platform         28.62
# 9                  Duck Hunt      NES       Shooter         28.31

# %%
# Visualisation into a table
HTML(Best_Candidates.to_html( classes= 'table table-striped table-bordered' ))
# Out:
# <table border="1" class="dataframe table table-striped table-bordered">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Platform</th>
#       <th>Genre</th>
#       <th>Global_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Wii Sports</td>
#       <td>Wii</td>
#       <td>Sports</td>
#       <td>82.74</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Super Mario Bros.</td>
#       <td>NES</td>
#       <td>Platform</td>
#       <td>40.24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Mario Kart Wii</td>
#       <td>Wii</td>
#       <td>Racing</td>
#       <td>35.82</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Wii Sports Resort</td>
#       <td>Wii</td>
#       <td>Sports</td>
#       <td>33.00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Pokemon Red/Pokemon Blue</td>
#       <td>GB</td>
#       <td>Role-Playing</td>
#       <td>31.37</td>
# ...

# %%
Best_Candidates.plot.bar(x="Name", y="Global_Sales", rot=70, title="best selling games globally");

plt.show(block=True)
